# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Exercise-1
#Task1
from PIL import Image
#image_colored = Image . open ("/content/drive/MyDrive/AI and ML/jujutsu-kaisen-fushiguro-toji-weapon-sword-muscles-hd-wallpaper-preview.jpg")
image_colored = Image . open ("/content/drive/MyDrive/AI ml/images (1).jpg")
display ( image_colored)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
#Task2
import numpy as np
# Convert the Pillow image to a NumPy array
image_array_colored = np . array ( image_colored )
# Define the cropping box (left , upper , right , lower )
left =0
upper = 0
right = 100
lower = 100
# Crop the image
cropped_image = image_colored . crop (( left , upper , right ,
lower ) )
# Display the cropped image
display ( cropped_image )
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
#Task3
#Red Channel
red_channel= image_array_colored.copy()
red_channel[:,:,1]=0
red_channel[:,:,2]=0
display(red_channel)
#Green Channel
green_channel= image_array_colored.copy()
green_channel[:,:,0]=0
green_channel[:,:,2]=0
display(green_channel)
#Blue Channel
blue_channel= image_array_colored.copy()
blue_channel[:,:,0]=0
blue_channel[:,:,1]=0
display(blue_channel)
# Out:
# array([[[129,   0,   0],
#         [130,   0,   0],
#         [136,   0,   0],
#         ...,
#         [100,   0,   0],
#         [ 74,   0,   0],
#         [102,   0,   0]],
#
#        [[127,   0,   0],
#         [128,   0,   0],
#         [131,   0,   0],
#         ...,
#         [139,   0,   0],
#         [125,   0,   0],
#         [125,   0,   0]],
#
#        [[124,   0,   0],
#         [125,   0,   0],
#         [127,   0,   0],
#         ...,
#         [ 89,   0,   0],
#         [138,   0,   0],
#         [151,   0,   0]],
#
#        ...,
#
#        [[121,   0,   0],
#         [106,   0,   0],
#         [116,   0,   0],
#         ...,
#         [100,   0,   0],
#         [102,   0,   0],
#         [108,   0,   0]],
#
#        [[107,   0,   0],
#         [105,   0,   0],
#         [110,   0,   0],
#         ...,
#         [ 69,   0,   0],
#         [ 71,   0,   0],
#         [ 77,   0,   0]],
#
#        [[117,   0,   0],
#         [115,   0,   0],
#         [120,   0,   0],
# ...

# %%
# Create a copy of the original image array to avoid modifying it directly
modified_image_array = image_array_colored.copy()

# Modify the top-left 100x100 pixels to 210
modified_image_array[0:100, 0:100, :] = 210

# Convert the modified NumPy array back to a PIL Image
modified_image = Image.fromarray(modified_image_array)

# Display the modified image
display(modified_image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %%
#Exercise-2
#Task1
import matplotlib.pyplot as plt
image_grayscale = Image . open ("/content/drive/MyDrive/AI ml/images (1).jpg")
# Display the grayscale image using matplotlib
plt.imshow(image_grayscale, cmap='gray')
plt.title('Grayscale Image')
plt.show()

# %%
#Task2
# Convert the Pillow image to a NumPy array, ensuring it's truly grayscale (mode 'L')
image_array_grayscale = np.array(image_grayscale.convert('L'))

# Get the dimensions of the image
height, width = image_array_grayscale.shape

# Calculate the cropping coordinates for a 150x150 section from the center
start_row = height // 2 - 75
end_row = height // 2 + 75
start_col = width // 2 - 75
end_col = width // 2 + 75

# Ensure the coordinates are within image bounds
start_row = max(0, start_row)
end_row = min(height, end_row)
start_col = max(0, start_col)
end_col = min(width, end_col)

# Extract the central 150x150 pixel section using NumPy array slicing
center_section = image_array_grayscale[start_row:end_row, start_col:end_col]

# Display the cropped image using matplotlib
plt.imshow(center_section, cmap='gray')
plt.title('Central 150x150 Pixel Section (Grayscale)')
plt.show()

# %%
#Task3
# Define the threshold value
threshold_value = 100

# Create a copy to avoid modifying the original grayscale array directly
binary_image_array = image_array_grayscale.copy()

# Apply the threshold: values below 100 to 0, values above 100 to 255
binary_image_array[binary_image_array < threshold_value] = 0
binary_image_array[binary_image_array >= threshold_value] = 255

# Convert the NumPy array back to a PIL Image
binary_image = Image.fromarray(binary_image_array.astype(np.uint8))

# Display the resulting binary image
plt.imshow(binary_image, cmap='gray')
plt.title('Thresholded Binary Image')
plt.show()

# %%
#Task4
# Rotate the grayscale image 90 degrees clockwise
rotated_image = image_grayscale.rotate(-90, expand=True)

# Display the rotated image using matplotlib
plt.imshow(rotated_image, cmap='gray')
plt.title('Rotated Image (90 degrees clockwise)')
plt.show()

# %%
#Task5
# The 'convert('RGB')' method in Pillow will replicate the single channel into three.
rgb_image = image_grayscale.convert('RGB')

# Display the converted RGB image using matplotlib
plt.imshow(rgb_image)
plt.title('Grayscale Image Converted to RGB')
plt.show()

# %%
#Exercise-3
#Task1
image= Image . open ("/content/drive/MyDrive/AI ml/images (1).jpg") . convert("L")
# Convert to NumPy array
image_array = np . array ( image )
# Get image dimensions
height , width = image_array . shape
# Reshape the image into a 2D array where each row represents a row of pixels
# This allows PCA to process each row as an observation and find patterns across pixel intensities
data = image_array . reshape ( height , width )
# Compute the mean of each column ( feature )
mean = np . mean ( data , axis =0)
# Subtract mean to center the data
centered_data = data - mean
# Compute covariance matrix
cov_matrix = np . cov ( centered_data , rowvar = False )
print("Covariance Matrix:")
print(cov_matrix)
print("Centered Data:")
print(centered_data)
# Out:
# Covariance Matrix:
# [[1742.00352545 1650.80209391 1489.56193579 ...  791.81443299
#    755.47379948  728.78040703]
#  [1650.80209391 1787.62974734 1618.31106778 ...  772.15469259
#    739.08255435  727.87401848]
#  [1489.56193579 1618.31106778 1643.57237861 ...  674.18198814
#    644.83486459  631.1238983 ]
#  ...
#  [ 791.81443299  772.15469259  674.18198814 ... 1614.26686609
#   1410.83152609 1191.91373324]
#  [ 755.47379948  739.08255435  644.83486459 ... 1410.83152609
#   1438.35257198 1177.33911116]
#  [ 728.78040703  727.87401848  631.1238983  ... 1191.91373324
#   1177.33911116 1382.38515571]]
# Centered Data:
# [[ 16.08247423  18.32474227  22.22164948 ...  24.11340206  -1.84020619
#    25.21134021]
#  [ 14.08247423  16.32474227  19.22164948 ...  63.11340206  49.15979381
#    48.21134021]
#  [ 12.08247423  13.32474227  15.22164948 ...  13.11340206  62.15979381
#    74.21134021]
#  ...
#  [-29.91752577 -43.67525773 -32.77835052 ...   4.11340206   7.15979381
#    11.21134021]
# ...

# %%
#Task2
# Compute eigenvalues and eigenvectors
eigenvalues , eigenvectors = np . linalg . eigh ( cov_matrix )
# Sort eigenvalues and corresponding eigenvectors in descending order
sorted_indices = np . argsort ( eigenvalues ) [:: -1]
eigenvalues = eigenvalues [ sorted_indices ]
eigenvectors = eigenvectors [: , sorted_indices ]
print("Eigenvalues:")
print(eigenvalues)
print("Eigen Vectors:")
print(eigenvectors)
# Plot the explained variance ratio
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt . plot ( np . cumsum ( explained_variance_ratio ) )
plt . title (" Cumulative Explained Variance ")
plt . xlabel (" Number of Components ")
plt . ylabel (" Cumulative Explained Variance ")
plt . grid ( True )
plt . show ()
# Out:
# Eigenvalues:
# [ 1.74710535e+05  1.01527800e+05  4.96499720e+04  2.49459422e+04
#   2.16955796e+04  1.09963173e+04  8.19592323e+03  7.61457939e+03
#   7.25231182e+03  6.39187979e+03  5.14493046e+03  3.72284784e+03
#   3.61227165e+03  3.12787903e+03  2.96277607e+03  2.47647612e+03
#   2.31045487e+03  2.16073378e+03  2.11438437e+03  1.76180869e+03
#   1.70117657e+03  1.65671585e+03  1.46765580e+03  1.37673024e+03
#   1.26938284e+03  1.20966590e+03  1.14783251e+03  1.07636120e+03
#   1.03391006e+03  9.85930224e+02  9.31956952e+02  8.41815269e+02
#   8.12947105e+02  8.04447535e+02  7.76219924e+02  7.15474495e+02
#   7.06857531e+02  7.06131907e+02  6.66846094e+02  6.31179333e+02
#   6.14133284e+02  5.99736009e+02  5.78667386e+02  5.54697627e+02
#   5.18068477e+02  5.08576260e+02  4.69688659e+02  4.57775353e+02
#   4.45242178e+02  4.23960825e+02  4.18190099e+02  4.06039641e+02
#   3.98935578e+02  3.80301657e+02  3.68973761e+02  3.59410020e+02
# ...

# %%
#Task-3
k_values = [10, 50, 100, 500]
for k in k_values:
    # Select the top k eigenvectors as principal components
    components_k = eigenvectors[:, :k]

    # Project the centered_data onto these k principal components
    compressed_data_k = np.dot(centered_data, components_k)

    # Reconstruct the image from the compressed data
    decompressed_data_k = np.dot(compressed_data_k, components_k.T) + mean

    # Reshape the decompressed data back to image dimensions
    decompressed_image_k = decompressed_data_k.reshape(height, width)

    # Display the original, compressed, and reconstructed images for the current k
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 3, 1)
    plt.imshow(image_array, cmap="gray")
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    # The compressed data is typically a lower-dimensional representation
    # We display it to show its existence, but it's not a direct 'image' in the visual sense
    # We might need to scale it for better visualization if desired, but for now just showing the structure
    plt.imshow(compressed_data_k, cmap="gray", aspect="auto")
    plt.title(f"Compressed Representation (k={k})")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(decompressed_image_k, cmap="gray")
    plt.title(f"Reconstructed Image (k={k})")
    plt.axis("off")

    plt.tight_layout()
    plt.show()
